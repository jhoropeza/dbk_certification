-- %%
%run ./_setup

-- %%
%python
# MAGIC %run "./_setup"

# Crear el esquema Silver si no existe
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {DA.silver}")

# Leer de Bronze usando el objeto DA
df_bronze = spark.read.table(f"{DA.bronze}.raw_transactions")

# Una transformación simple (ej: filtrar montos mayores a 0)
df_silver = df_bronze.filter("amount > 0")

# Guardar en la capa Silver
df_silver.write.mode("overwrite").saveAsTable(f"{DA.silver}.cleaned_transactions")

print(f"✅ Tabla Silver creada en: {DA.silver}")
