# %%
dftoWrite= spark.read.format("delta").table("my_catalog.default.orders")

# %%
dftoWrite.write.mode("overwrite").saveAsTable("my_catalog.bronze_wl.orders_bronze")

# %%
# %sql
select * from my_catalog.bronze_wl.orders_bronze
