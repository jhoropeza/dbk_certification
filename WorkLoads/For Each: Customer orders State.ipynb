# %%
my_catalog = dbutils.widgets.get("catalog")
my_schema = dbutils.widgets.get("schema")

# %%
# %sql
use catalog my_catalog;
use schema bronze_wl;

# %%
# Getting state code from wodget
state = dbutils.widgets.get("state")
print(f"Running for state: {state}")

# %%
df = spark.sql(f"""
               SELECT *,
                        TO_DATE(order_datetime ) as order_Date,
                        CASE WHEN number_of_line_items> 2 THEN true ELSE false END AS is_large_order
                FROM customers_orders_silver
                WHERE state = '{state}'
                """)

# %%
df.show()

# %%
# Save to Delta table, one per state specified in the loop:
clean_state = state.replace(' ', '_').lower()
table_name = f"customers_orders_{clean_state}_silver"

# %%
print(table_name)

# %%
## Reading and transforming data from master customers_ordes_silve table
## Transforming order data from unix timestamp to date and adding is_large_order column



df.write.mode("overwrite").saveAsTable(table_name)
