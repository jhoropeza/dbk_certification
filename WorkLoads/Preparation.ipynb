# %%
# %sql
CREATE SCHEMA IF NOT EXISTS my_catalog.silver_wl;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS my_catalog.my_schema.staging;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS my_catalog.bronze_wl.trigger_storage_location;

# %%
dbutils.fs.cp("/Volumes/my_catalog/my_schema/staging/customers.json", "/Volumes/my_catalog/bronze_wl/trigger_storage_location")

# %%
# %sql
use catalog `my_catalog`;
SELECT * FROM information_schema.columns
WHERE table_catalog = 'my_catalog'
  AND table_schema = 'bronze_wl'
  AND table_name = 'orders_bronze';

# %%
# %sql
use catalog `my_catalog`; select * from `bronze_wl`.`orders_bronze` limit 100;

# %%
# %sql
select * from bronze_wl.customer_orders_silver;

# %%
# %sql
select * from bronze_wl.customer_sales_silver;
