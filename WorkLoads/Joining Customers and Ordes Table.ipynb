# %%
my_catalog = dbutils.widgets.get("catalog")
my_schema = dbutils.widgets.get("schema")

# %%
# %sql
use catalog my_catalog;
use schema bronze_wl;

# %%
# %sql
CREATE OR REPLACE TABLE customers_orders_silver AS
select 
  c.customer_id,
  c.customer_name,
  c.state,
  c.city,
  o.order_number,
  o.order_datetime,
  o.number_of_line_items,
  o.promo_info
from customers_bronze c
join
orders_bronze o
on c.customer_id = o.customer_id;
